# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(
    r"C:\Users\claud\OneDrive\Documentos\GitHub\SEMANA 4  VISUALISACAO DE DADOS\github.com\cfneves\visualizacao-de-dados.git\turma-visualizacao-de-dados\alunos\claudi_borges\Semana_5\base_rh.csv",
    sep=";",
    encoding="cp1252",
    decimal=","
)

df["Data_Admissao"] = pd.to_datetime(
    df["Data_Admissao"], format="%d/%m/%Y", errors="coerce"
)

print(f"Dataset carregado: {df.shape[0]} linhas x {df.shape[1]} colunas")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 import pandas as pd
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 df = pd.read_csv(
#       5     r"C:\Users\claud\turma-visualizacao-de-dados\alunos\claudi_borges\semana_5\base_rh.csv",
#       6     sep=";",
#       7     encoding="cp1252",
#
# ...

# %%
# print(df)               # Mostra o DataFrame completo
print(df.head())  # Mostra as primeiras 5 linhas
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # print(df)               # Mostra o DataFrame completo
# ----> 2 print(df.head())  # Mostra as primeiras 5 linhas
#
# NameError: name 'df' is not defined

# %%
print(df.head(10))  # 10 primeiras linhas
print(df.tail())  # últimas 5 linhas
print(df.columns)  # nomes das colunas
print(df.info())  # estrutura da base
print(df.describe())  # estatísticas numéricas
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(df.head(10))  # 10 primeiras linhas
#       2 print(df.tail())  # últimas 5 linhas
#       3 print(df.columns)  # nomes das colunas
#       4 print(df.info())  # estrutura da base
#
# NameError: name 'df' is not defined

# %%
# Uma coluna → Series
salarios = df["Salario"]
print(f"Tipo  : {type(salarios)}")
print(f"shape : {salarios.shape}")  # (1000,) — 1 dimensão
print(f"dtype : {salarios.dtype}")
print(salarios.head(4))

print("\n" + "─" * 38)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Uma coluna → Series
# ----> 2 salarios = df["Salario"]
#       3 print(f"Tipo  : {type(salarios)}")
#       4 print(f"shape : {salarios.shape}")  # (1000,) — 1 dimensão
#       5 print(f"dtype : {salarios.dtype}")
#
# NameError: name 'df' is not defined

# %%
# Duas colunas → DataFrame
sub = df[["Nome", "Salario"]]
print(f"\nTipo  : {type(sub)}")
print(f"shape : {sub.shape}")  # (1000, 2) — 2 dimensões
print(sub.head(3))

print("\n" + "─" * 38)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Duas colunas → DataFrame
# ----> 2 sub = df[["Nome", "Salario"]]
#       3 print(f"\nTipo  : {type(sub)}")
#       4 print(f"shape : {sub.shape}")  # (1000, 2) — 2 dimensões
#       5 print(sub.head(3))
#
# NameError: name 'df' is not defined

# %%
# Estatísticas — só funcionam direto na Series
print(f"\nMédia   : R$ {salarios.mean():,.2f}")
print(f"Mediana : R$ {salarios.median():,.2f}")
print(f"Mínimo  : R$ {salarios.min():,.2f}")
print(f"Máximo  : R$ {salarios.max():,.2f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Estatísticas — só funcionam direto na Series
# ----> 2 print(f"\nMédia   : R$ {salarios.mean():,.2f}")
#       3 print(f"Mediana : R$ {salarios.median():,.2f}")
#       4 print(f"Mínimo  : R$ {salarios.min():,.2f}")
#       5 print(f"Máximo  : R$ {salarios.max():,.2f}")
#
# NameError: name 'salarios' is not defined

# %%
# Estatísticas — só funcionam direto na Series
print(f"\nMédia   : R$ {salarios.mean():,.2f}")
print(f"Mediana : R$ {salarios.median():,.2f}")
print(f"Mínimo  : R$ {salarios.min():,.2f}")
print(f"Máximo  : R$ {salarios.max():,.2f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Estatísticas — só funcionam direto na Series
# ----> 2 print(f"\nMédia   : R$ {salarios.mean():,.2f}")
#       3 print(f"Mediana : R$ {salarios.median():,.2f}")
#       4 print(f"Mínimo  : R$ {salarios.min():,.2f}")
#       5 print(f"Máximo  : R$ {salarios.max():,.2f}")
#
# NameError: name 'salarios' is not defined
