# %%
import pandas as pd      # biblioteca de análise de dados
import re                # expressões regulares (para limpar texto)
from datetime import datetime  # para trabalhar com datas

# Confirmar que as importações funcionaram
print('✓ pandas versão:', pd.__version__)
print('✓ Bibliotecas importadas com sucesso!') # Definir o caminho completo (ajuste para o seu local exato)

# %%
# indice_padrão
print("indice padrão:", df.index)

# set_index: ID_Funcionario vira o endereço.
df.idx=df.set_index("ID-Funcionario")
print("\nFuncionario ID 5:", df_idx.loc[5][["Nome", "Departamento", "salario"]])

# reset_index: volta ao numero padrão

df_volta= df_index.reset_index()
print("\nColunas após reset: {df_volta df_volta.columns.tolist()}")
#indice apos filtro (nao começa no 0)

# %%
pip install matplotlib

# %%
pip install pandas openpyxl
